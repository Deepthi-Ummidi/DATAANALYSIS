# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree
from IPython.display import Image

# %%
df=pd.read_csv('/content/demoDT.csv')
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     0
# 3      D        85            75           48     1
# 4      E        60            82           55     0
# 5      F        72            78           60     0
# 6      G        88            85           45     0
# 7      H        64            70           58     1
# 8      I        90            88           42     0
# 9      J        68            72           65     0
# 10     K        75            79           57     0
# 11     L        82            86           49     0
# 12     M        58            65           63     1
# 13     N        77            76           52     0
# 14     O        94            91           40     1
# 15     P        63            74           61     0
# 16     Q        79            83           47     0
# ...

# %%
features_coals=['Literacy',' Cleanliness',' Crime_Rate']
feature=df[features_coals]
Target=df.good

# %%
DT=DecisionTreeClassifier()
DT=DT.fit(feature,Target)

# %%
l=int(input("enter literacy:"))
cl=int(input("enter cleanliness:"))
cr=int(input("enter crimeRate:"))
pred=DT.predict([[l,cl,cr]])
if pred==1:
    print("good state")
else:
  print("bad state")
# Out:
# enter literacy:92
# enter cleanliness:90
# enter crimerate:54
# bad state
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(DT)
# Out:
# [Text(0.4, 0.9285714285714286, 'x[1] <= 67.5\ngini = 0.473\nsamples = 26\nvalue = [16, 10]'),
#  Text(0.3, 0.7857142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.7857142857142857, 'x[2] <= 48.5\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(0.2, 0.6428571428571429, 'x[0] <= 81.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3, 0.5, 'x[0] <= 87.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.2, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4, 0.35714285714285715, 'x[1] <= 89.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.6428571428571429, 'x[1] <= 73.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.7, 0.5, 'x[2] <= 58.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
# ...
